# %%
# 公共数据
import pandas as pd

enterprise_info_with_credit_df = pd.read_excel('dataset/附件1：123家有信贷记录企业的相关数据.xlsx', sheet_name=0)
in_invoice_with_credit_df = pd.read_excel('dataset/附件1：123家有信贷记录企业的相关数据.xlsx', sheet_name=1)
out_invoice_with_credit_df = pd.read_excel('dataset/附件1：123家有信贷记录企业的相关数据.xlsx', sheet_name=2)
enterprise_info_without_credit_df = pd.read_excel('dataset/附件2：302家无信贷记录企业的相关数据.xlsx', sheet_name=0)
out_invoice_without_credit_df = pd.read_excel('dataset/附件2：302家无信贷记录企业的相关数据.xlsx', sheet_name=1)
in_invoice_without_credit_df = pd.read_excel('dataset/附件2：302家无信贷记录企业的相关数据.xlsx', sheet_name=2)
bank_annual_interest_rate_and_client_wastage_rate_df = pd.read_excel('dataset/附件3：银行贷款年利率与客户流失率关系的统计数据 - 规范列名.xlsx')

# %%
    print(enterprise_number)
# Out:
# E1
# E2
# E3
# E4
# E5
# E6
# E7
# E8
# E9
# E10
# E11
# E12
# E13
# E14
# E15
# E16
# E17
# E18
# E19
# E20
# E21
# E22
# E23
# E24
# E25
# E26
# E27
# E28
# E29
# E30
# E31
# E32
# E33
# E34
# E35
# E36
# E37
# E38
# E39
# E40
# E41
# E42
# E43
# E44
# E45
# E46
# E47
# E48
# E49
# E50
# E51
# E52
# E53
# E54
# E55
# E56
# E57
# E58
# E59
# E60
# E61
# E62
# E63
# E64
# E65
# E66
# E67
# E68
# E69
# E70
# E71
# E72
# E73
# E74
# E75
# E76
# E77
# E78
# E79
# E80
# E81
# E82
# E83
# E84
# E85
# E86
# E87
# E88
# E89
# E90
# E91
# E92
# E93
# E94
# E95
# E96
# E97
# E98
# E99
# E100
# E101
# E102
# E103
# E104
# E105
# E106
# E107
# E108
# E109
# E110
# E111
# E112
# E113
# E114
# E115
# E116
# E117
# E118
# E119
# E120
# E121
# E122
# E123

# %%
in_invoice_with_credit_df[in_invoice_with_credit_df.企业代号=='E1'].金额.values
# Out:
# array([ -943.4 , -4780.24,   943.4 , ...,  3656.64,   336.29,   284.07])

# %%
for enterprise_number in in_invoice_with_credit_df.企业代号.unique():
    enterprise_money = in_invoice_with_credit_df[in_invoice_with_credit_df.企业代号==enterprise_number].金额.values
    enterprise_date = in_invoice_with_credit_df[in_invoice_with_credit_df.企业代号==enterprise_number].开票日期.values
    in_invoice_with_credit_month_df = pd.DataFrame({'金额': enterprise_money}, index=enterprise_date).resample('M').sum()
    print(enterprise_number, in_invoice_with_credit_month_df.std() / in_invoice_with_credit_month_df.mean())
# Out:
# E1 金额    0.508226
# dtype: float64
# E2 金额    0.708538
# dtype: float64
# E3 金额    0.651519
# dtype: float64
# E4 金额    1.778225
# dtype: float64
# E5 金额    0.981818
# dtype: float64
# E6 金额    0.705255
# dtype: float64
# E7 金额    0.695123
# dtype: float64
# E8 金额    0.450634
# dtype: float64
# E9 金额    0.446644
# dtype: float64
# E10 金额    0.704607
# dtype: float64
# E11 金额    1.079951
# dtype: float64
# E12 金额    1.600996
# dtype: float64
# E13 金额    0.422589
# dtype: float64
# E14 金额    1.064185
# dtype: float64
# E15 金额    1.878101
# dtype: float64
# E16 金额    1.192954
# dtype: float64
# E17 金额    0.661083
# dtype: float64
# E18 金额    1.021627
# dtype: float64
# E19 金额    0.48988
# dtype: float64
# E20 金额    0.665691
# dtype: float64
# E21 金额    0.916335
# dtype: float64
# E22 金额    1.036207
# dtype: float64
# E23 金额    0.358737
# dtype: float64
# E24 金额    0.668289
# dtype: float64
# E25 金额    0.999235
# dtype: float64
# E26 金额    0.675551
# dtype: float64
# E27 金额    0.547678
# dtype: float64
# E28 金额    1.994991
# dtype: float64
# E29 金额    5.302257
# dtype: float64
# E30 金额    1.249164
# dtype: float64
# E31 金额    0.929543
# dtype: float64
# E32 金额    0.872494
# dtype: float64
# E33 金额    0.672156
# dtype: float64
# E34 金额    1.781951
# dtype: float64
# E35 金额    0.879961
# dtype: float64
# E36 金额    0.360334
# dtype: float64
# E37 金额    0.692706
# dtype: float64
# E38 金额    2.320371
# dtype: float64
# E39 金额    2.008358
# dtype: float64
# E40 金额    1.040786
# dtype: float64
# E41 金额    0.84437
# dtype: float64
# E42 金额    2.296986
# dtype: float64
# E43 金额    2.5825
# dtype: float64
# E44 金额    0.762334
# dtype: float64
# E45 金额    1.225123
# dtype: float64
# E46 金额    0.558316
# dtype: float64
# E47 金额    0.379814
# dtype: float64
# E48 金额    0.968907
# dtype: float64
# E49 金额    1.331888
# dtype: float64
# E50 金额    4.118912
# dtype: float64
# E51 金额    0.778539
# dtype: float64
# E52 金额    1.844246
# dtype: float64
# E53 金额    0.650768
# dtype: float64
# E54 金额    0.755706
# dtype: float64
# E55 金额    1.288799
# dtype: float64
# E56 金额    0.852648
# dtype: float64
# E57 金额    1.675856
# dtype: float64
# E58 金额    2.136421
# dtype: float64
# E59 金额    0.548878
# dtype: float64
# E60 金额    2.609789
# dtype: float64
# E61 金额    1.212611
# dtype: float64
# E62 金额    1.861802
# dtype: float64
# E63 金额    1.331961
# dtype: float64
# E64 金额    2.654052
# dtype: float64
# E65 金额    1.044844
# dtype: float64
# E66 金额    1.062957
# dtype: float64
# E67 金额    2.420055
# dtype: float64
# E68 金额    2.116926
# dtype: float64
# E69 金额   NaN
# dtype: float64
# E70 金额    1.039555
# dtype: float64
# E71 金额    2.730678
# dtype: float64
# E72 金额    2.230739
# dtype: float64
# E73 金额    0.684647
# dtype: float64
# E74 金额    3.160918
# dtype: float64
# E75 金额    1.080491
# dtype: float64
# E76 金额    2.117075
# dtype: float64
# E77 金额    2.078444
# dtype: float64
# E78 金额    0.978593
# dtype: float64
# E79 金额    0.680652
# dtype: float64
# E80 金额    3.170171
# dtype: float64
# E81 金额    0.879306
# dtype: float64
# E82 金额    1.027635
# dtype: float64
# E83 金额    0.679987
# dtype: float64
# E84 金额    1.585809
# dtype: float64
# E85 金额    2.363213
# dtype: float64
# E86 金额    3.672157
# dtype: float64
# E87 金额    1.174497
# dtype: float64
# E88 金额    1.259332
# dtype: float64
# E89 金额    5.848623
# dtype: float64
# E90 金额    2.216011
# dtype: float64
# E91 金额    0.785785
# dtype: float64
# E92 金额    1.304677
# dtype: float64
# E93 金额    1.52395
# dtype: float64
# E94 金额    4.592481
# dtype: float64
# E95 金额    2.971426
# dtype: float64
# E96 金额    4.8811
# dtype: float64
# E97 金额    1.318029
# dtype: float64
# E98 金额    2.817354
# dtype: float64
# E99 金额    3.268201
# dtype: float64
# E100 金额    1.569179
# dtype: float64
# E101 金额    2.999837
# dtype: float64
# E102 金额    0.399198
# dtype: float64
# E103 金额    2.279286
# dtype: float64
# E104 金额   NaN
# dtype: float64
# E105 金额    2.53683
# dtype: float64
# E106 金额    2.615962
# dtype: float64
# E107 金额    3.630758
# dtype: float64
# E108 金额    1.58674
# dtype: float64
# E109 金额    1.952883
# dtype: float64
# E110 金额    2.861027
# dtype: float64
# E111 金额    1.818329
# dtype: float64
# E112 金额    1.073444
# dtype: float64
# E113 金额    3.78207
# dtype: float64
# E114 金额    1.666653
# dtype: float64
# E115 金额    2.638993
# dtype: float64
# E116 金额    1.559271
# dtype: float64
# E117 金额    2.437029
# dtype: float64
# E118 金额    4.480435
# dtype: float64
# E119 金额    0.82323
# dtype: float64
# E120 金额    3.271928
# dtype: float64
# E121 金额    0.794384
# dtype: float64
# E122 金额    2.079692
# dtype: float64
# E123 金额    2.763854
# dtype: float64

# %%
# Out:
# 金额    0.61726
# dtype: float64
